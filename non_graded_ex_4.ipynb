# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time


card_deck = [
    {"Name": "Diablo", "Health": 100, "Attack": 90, "Defense": 60},
    {"Name": "Medusa", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Jester", "Health": 120, "Attack": 60, "Defense": 90},
    {"Name": "Troll", "Health": 150, "Attack": 40, "Defense": 94},
    {"Name": "Specter", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Mist", "Health": 100, "Attack": 75, "Defense": 65},
    {"Name": "Savage", "Health": 100, "Attack": 90, "Defense": 50},
    {"Name": "Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    {"Name": "Wimp", "Health": 110, "Attack": 40, "Defense": 85},
    {"Name": "Sorcerer", "Health": 100, "Attack": 70, "Defense": 55}
]

deck_size = 5  

player_deck = random.sample(card_deck, deck_size)
remaining_deck = [card for card in card_deck if card not in player_deck]
opponent_deck = random.sample(remaining_deck, deck_size)

def display_card(card):
    print(f"Name: {card['Name']}")
    print(f"Health: {card['Health']}")
    print(f"Attack: {card['Attack']}")
    print(f"Defense: {card['Defense']}")
    print("-" * 20)

def player_attack(player_card, opponent_card):
    print(f"\nYour {player_card['Name']} is attacking opponent's {opponent_card['Name']}!")

    if player_card['Name'] == opponent_card['Name']:
        print(f"The opponent's {opponent_card['Name']} is the same card. No damage dealt to the opponent.")
        return False

    if opponent_card['Defense'] > 0:
        if player_card['Attack'] >= opponent_card['Defense']:
            remaining_attack = player_card['Attack'] - opponent_card['Defense']
            opponent_card['Defense'] = 0
            opponent_card['Health'] -= remaining_attack
        else:
            opponent_card['Defense'] -= player_card['Attack']
    else:
        opponent_card['Health'] -= player_card['Attack']

    print(f"Opponent's {opponent_card['Name']} after the attack:")
    display_card(opponent_card)

    if opponent_card['Health'] <= 0:
        print(f"Opponent's {opponent_card['Name']} has been defeated!")
        return True
    return False

def opponent_attack(player_card, opponent_card):
    print(f"\nOpponent's {opponent_card['Name']} is attacking your {player_card['Name']}!")

    if player_card['Name'] == opponent_card['Name']:
        print(f"Opponent and player have the same card ({player_card['Name']}). Only player's card will take damage.")

    
    if player_card['Defense'] > 0:
        if opponent_card['Attack'] >= player_card['Defense']:
            remaining_attack = opponent_card['Attack'] - player_card['Defense']
            player_card['Defense'] = 0
            player_card['Health'] -= remaining_attack
        else:
            player_card['Defense'] -= opponent_card['Attack']
    else:
        player_card['Health'] -= opponent_card['Attack']


    print(f"Your {player_card['Name']} after the attack:")
    display_card(player_card)


    if player_card['Health'] <= 0:
        print(f"Your {player_card['Name']} has been defeated!")
        return True
    return False

def choose_card(deck, message):
    """让玩家选择一张卡牌"""
    while True:
        try:
            choice = int(input(message)) - 1
            if 0 <= choice < len(deck):
                return deck[choice]
            else:
                print(f"Please enter a number between 1 and {len(deck)}.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

while player_deck and opponent_deck:
    
    print("\nYour cards:")
    for idx, card in enumerate(player_deck):
        print(f"{idx + 1}. {card['Name']} (Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']})")

    
    opponent_card = random.choice(opponent_deck)
    print("\nOpponent's card:")
    display_card(opponent_card)

    
    player_card = choose_card(player_deck, f"Choose your card (1-{len(player_deck)}): ")


    if player_attack(player_card, opponent_card):
        opponent_deck.remove(opponent_card)  

    time.sleep(2)

    if not opponent_deck:
        print("\nCongratulations! You have defeated all opponent's cards. You win!")
        break

    print("\nOpponent's turn...")

    opponent_card = random.choice(opponent_deck)
    
    player_card = random.choice(player_deck)


    if opponent_attack(player_card, opponent_card):
        player_deck.remove(player_card)  

    time.sleep(2)

    if not player_deck:
        print("\nSorry! All your cards have been defeated. Opponent wins!")
        break


if not player_deck:
    print("\nGame Over! The opponent won.")
elif not opponent_deck:
    print("\nGame Over! You won!")
# Out:
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 70)
# 2. Specter (Health: 100, Attack: 70, Defense: 70)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
# --------------------
# Invalid input. Please enter a valid number.
#
# Your Medusa is attacking opponent's Sorcerer!
# Opponent's Sorcerer after the attack:
# Name: Sorcerer
# Health: 85
# Attack: 70
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Sorcerer is attacking your Specter!
# Your Specter after the attack:
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 70)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
# --------------------
#
# Your Savage is attacking opponent's Jester!
# Opponent's Jester after the attack:
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Jester is attacking your Medusa!
# Your Medusa after the attack:
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 10
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 94)
# 5. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 0
# --------------------
#
# Your Savage is attacking opponent's Jester!
# Opponent's Jester after the attack:
# Name: Jester
# Health: 30
# Attack: 60
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Troll!
# Your Troll after the attack:
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 4
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Troll (Health: 150, Attack: 40, Defense: 4)
# 5. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Jester
# Health: 30
# Attack: 60
# Defense: 0
# --------------------
#
# Your Savage is attacking opponent's Jester!
# Opponent's Jester after the attack:
# Name: Jester
# Health: -60
# Attack: 60
# Defense: 0
# --------------------
# Opponent's Jester has been defeated!
#
# Opponent's turn...
#
# Opponent's Mist is attacking your Troll!
# Your Troll after the attack:
# Name: Troll
# Health: 79
# Attack: 40
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Troll (Health: 79, Attack: 40, Defense: 0)
# 5. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
# --------------------
#
# Your Savage is attacking opponent's Diablo!
# Opponent's Diablo after the attack:
# Name: Diablo
# Health: 70
# Attack: 90
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Troll!
# Your Troll after the attack:
# Name: Troll
# Health: -11
# Attack: 40
# Defense: 0
# --------------------
# Your Troll has been defeated!
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 100, Attack: 90, Defense: 50)
# 4. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
# --------------------
#
# Your Savage is attacking opponent's Wimp!
# Opponent's Wimp after the attack:
# Name: Wimp
# Health: 105
# Attack: 40
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Sorcerer is attacking your Savage!
# Your Savage after the attack:
# Name: Savage
# Health: 80
# Attack: 90
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 80, Attack: 90, Defense: 0)
# 4. Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Opponent's card:
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
# --------------------
#
# Your Savage is attacking opponent's Mist!
# Opponent's Mist after the attack:
# Name: Mist
# Health: 75
# Attack: 75
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Marauder!
# Your Marauder after the attack:
# Name: Marauder
# Health: 60
# Attack: 85
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 100, Attack: 70, Defense: 0)
# 3. Savage (Health: 80, Attack: 90, Defense: 0)
# 4. Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Opponent's card:
# Name: Mist
# Health: 75
# Attack: 75
# Defense: 0
# --------------------
#
# Your Savage is attacking opponent's Mist!
# Opponent's Mist after the attack:
# Name: Mist
# Health: -15
# Attack: 75
# Defense: 0
# --------------------
# Opponent's Mist has been defeated!
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Specter!
# Your Specter after the attack:
# Name: Specter
# Health: 10
# Attack: 70
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 10, Attack: 70, Defense: 0)
# 3. Savage (Health: 80, Attack: 90, Defense: 0)
# 4. Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Opponent's card:
# Name: Wimp
# Health: 105
# Attack: 40
# Defense: 0
# --------------------
#
# Your Savage is attacking opponent's Wimp!
# Opponent's Wimp after the attack:
# Name: Wimp
# Health: 15
# Attack: 40
# Defense: 0
# --------------------
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Savage!
# Your Savage after the attack:
# Name: Savage
# Health: -10
# Attack: 90
# Defense: 0
# --------------------
# Your Savage has been defeated!
#
# Your cards:
# 1. Medusa (Health: 100, Attack: 70, Defense: 10)
# 2. Specter (Health: 10, Attack: 70, Defense: 0)
# 3. Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Opponent's card:
# Name: Sorcerer
# Health: 85
# Attack: 70
# Defense: 0
# --------------------
#
# Your Marauder is attacking opponent's Sorcerer!
# Opponent's Sorcerer after the attack:
# Name: Sorcerer
# Health: 0
# Attack: 70
# Defense: 0
# --------------------
# Opponent's Sorcerer has been defeated!
#
# Opponent's turn...
#
# Opponent's Diablo is attacking your Medusa!
# Your Medusa after the attack:
# Name: Medusa
# Health: 20
# Attack: 70
# Defense: 0
# --------------------
#
# Your cards:
# 1. Medusa (Health: 20, Attack: 70, Defense: 0)
# 2. Specter (Health: 10, Attack: 70, Defense: 0)
# 3. Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Opponent's card:
# Name: Diablo
# Health: 70
# Attack: 90
# Defense: 0
# --------------------
#
# Your Marauder is attacking opponent's Diablo!
# Opponent's Diablo after the attack:
# Name: Diablo
# Health: -15
# Attack: 90
# Defense: 0
# --------------------
# Opponent's Diablo has been defeated!
#
# Opponent's turn...
#
# Opponent's Wimp is attacking your Medusa!
# Your Medusa after the attack:
# Name: Medusa
# Health: -20
# Attack: 70
# Defense: 0
# --------------------
# Your Medusa has been defeated!
#
# Your cards:
# 1. Specter (Health: 10, Attack: 70, Defense: 0)
# 2. Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Opponent's card:
# Name: Wimp
# Health: 15
# Attack: 40
# Defense: 0
# --------------------
# Please enter a number between 1 and 2.
#
# Your Marauder is attacking opponent's Wimp!
# Opponent's Wimp after the attack:
# Name: Wimp
# Health: -70
# Attack: 40
# Defense: 0
# --------------------
# Opponent's Wimp has been defeated!
#
# Congratulations! You have defeated all opponent's cards. You win!
#
# Game Over! You won!
